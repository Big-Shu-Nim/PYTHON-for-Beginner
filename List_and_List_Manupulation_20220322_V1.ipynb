# %% [markdown]
# <a href="https://colab.research.google.com/github/Big-Shu-Nim/PYTHON_Basic_Syntax/blob/main/List_and_List_Manupulation_20220322_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bool_,int_,float_,str_=True, 0, 0.0, ""

# %%
list1=[bool_,int_,float_,str_]

for i in range(list1):
  type(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-93533ac1a1ae> in <module>()
#       1 list1=[bool_,int_,float_,str_]
#       2
# ----> 3 for i in range(list1):
#       4   type(list1)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# 아 이 어떻ㅔ 했는 까먹었다.

# %%
print("100")
print("%d" % 100)
# Out:
# 100
# 100

# %%
print("100+100")
print("%d" % 100+100)
# Out:
# 100+100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-93d9dd14e58d> in <module>()
#       1 print("100+100")
# ----> 2 print("%d" % 100+100)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("%d %d" % (100,200) )
# Out:
# 100 200

# %%
s1, s2, s3 = '100', '100.123', '99999'
print(s1, s2, s3)
# Out:
# 100 100.123 99999

# %%
str(s1)+'1'
#신기하게 문자화된 숫자끼리는 사칙연산이 가능하다.
# Out:
# '1001'

# %%
while True :
  print('hello', end='')
  # cltr +c doesn't work.
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e023334dbba6> in <module>()
#       1 while True :
# ----> 2   print('hello', end='')
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ...

# %%
for i in range(1, 100) :
  print('for문을 %d번 실행했습니다' %i)
  break
# Out:
# for문을 1번 실행했습니다

# %%
aa= [10,20,30,40]
print(aa)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# %d번 이해가 안된다.

# %%
aa = []
aa.append(0)
aa.append(0)
aa.append(0)
aa.append(0)
print(aa)
# Out:
# [0, 0, 0, 0]

# %%
aa= [10,20,30,40]
aa = []
for i in range(0, 100) :
  aa.append(0)
len(aa)
# Out:
# 100

# %%
aa= []
for i in range(0,4):
   aa.append(0)
for i in range( 0,4) :
  aa[i] = int(input(str(i+1)+'번째 숫자 :'))
sum = 0
for i in range(0,4) :
  sum = sum +aa[i]
print(' 합계 ==> %d' %sum)
# Out:
# 1번째 숫자 :1
# 2번째 숫자 :2
# 3번째 숫자 :5
# 4번째 숫자 :8
#  합계 ==> 16

# %%
aa = [10, 20, 30, 40]
print(aa[-1]
      # 시식 사용할때 "%d 만큼 사용하고' 사용한다는 표식으로 % 작성후 앞에 %d 만큼 숫자를 써줘야한다.

# %%
aa = [10, 20, 30, 40]

print(aa[0:5])
print(aa[0:4]) #aa[0] aa[1] aa[2] aa[[3] 

print(aa[0:2]) # 그냥 갯수 생각하고 할때는 직관적 가능 특정 번호 호출할때 좀 귀찬ㅎ/
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]
# [10, 20]

# %%
mylist= [30,10,20]
print(' my list : %s' % mylist)
# Out:
#  my list : [30, 10, 20]

# %%
mylist.append(40)
print('The imapact of append(40) : %s' % mylist)
# Out:
# The imapact of append(40) : [30, 10, 20, 40]

# %%
print("The arguments of append(40) with pop() : %s" % mylist.pop())
print('The imapc of pop(): %s' % mylist)
# Out:
# The arguments of append(40) with pop() : 40
# The imapc of pop(): [30, 10, 20]
